# %%
import pandas as pd

# %%
from google.colab import files

# %%
upload=files.upload()
# Out:
#      <input type="file" id="files-c47490e1-88b3-4b69-83a5-2c7f784b14c5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c47490e1-88b3-4b69-83a5-2c7f784b14c5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# Missing values

# %%
df.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %% [markdown]
# Descriptive Statistics of dataset

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# Dimensions of the dataset

# %%
rows , columns = df.shape

# %%
print("Number of rows",rows)
# Out:
# Number of rows 150

# %%
print("Number of columns",columns)
# Out:
# Number of columns 6

# %% [markdown]
# Display datatypes

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %% [markdown]
# Convert the data types from one to another

# %%
df['Id'] = df['Id'].astype(float)

# %%
df['SepalLengthCm'] = df['SepalLengthCm'].astype(int)

# %%
df['SepalWidthCm'] = df['SepalWidthCm'].astype(int)

# %%
df['PetalLengthCm'] = df['PetalLengthCm'].astype(int)

# %%
df['PetalWidthCm'] = df['PetalWidthCm'].astype(int)

# %%
df
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1.0              5             3              1             0
# 1      2.0              4             3              1             0
# 2      3.0              4             3              1             0
# 3      4.0              4             3              1             0
# 4      5.0              5             3              1             0
# ..     ...            ...           ...            ...           ...
# 145  146.0              6             3              5             2
# 146  147.0              6             2              5             1
# 147  148.0              6             3              5             2
# 148  149.0              6             3              5             2
# 149  150.0              5             3              5             1
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %% [markdown]
# Seprate Categorical and Numerical Attribute

# %%
categorical_attributes = df.select_dtypes(include=['object'])
numerical_attributes = df.select_dtypes(exclude=['object'])

# %%
print("Categorical Attributes:")
print(categorical_attributes.columns.tolist())
# Out:
# Categorical Attributes:
# ['Species']

# %%
print("Numerical Attributes:")
print(numerical_attributes.columns.tolist())
# Out:
# Numerical Attributes:
# ['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']

# %% [markdown]
# Unique Values

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# Converting  categorical to numerical attributes

# %%
df['Species'] = df['Species'].replace(['Iris-setosa','Iris-versicolor','Iris-virginica'],[0,1,2],inplace=False)
df
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1.0              5             3              1             0        0
# 1      2.0              4             3              1             0        0
# 2      3.0              4             3              1             0        0
# 3      4.0              4             3              1             0        0
# 4      5.0              5             3              1             0        0
# ..     ...            ...           ...            ...           ...      ...
# 145  146.0              6             3              5             2        2
# 146  147.0              6             2              5             1        2
# 147  148.0              6             3              5             2        2
# 148  149.0              6             3              5             2        2
# 149  150.0              5             3              5             1        2
#
# [150 rows x 6 columns]

# %%
df_encoded = pd.get_dummies(df ,columns=["Species"], drop_first=True)
df
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1.0              5             3              1             0        0
# 1      2.0              4             3              1             0        0
# 2      3.0              4             3              1             0        0
# 3      4.0              4             3              1             0        0
# 4      5.0              5             3              1             0        0
# ..     ...            ...           ...            ...           ...      ...
# 145  146.0              6             3              5             2        2
# 146  147.0              6             2              5             1        2
# 147  148.0              6             3              5             2        2
# 148  149.0              6             3              5             2        2
# 149  150.0              5             3              5             1        2
#
# [150 rows x 6 columns]

# %%
from sklearn import preprocessing

# %%
label_encoder = preprocessing.LabelEncoder()
df['Species'] = label_encoder.fit_transform(df['Species'])
df
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1.0              5             3              1             0        0
# 1      2.0              4             3              1             0        0
# 2      3.0              4             3              1             0        0
# 3      4.0              4             3              1             0        0
# 4      5.0              5             3              1             0        0
# ..     ...            ...           ...            ...           ...      ...
# 145  146.0              6             3              5             2        2
# 146  147.0              6             2              5             1        2
# 147  148.0              6             3              5             2        2
# 148  149.0              6             3              5             2        2
# 149  150.0              5             3              5             1        2
#
# [150 rows x 6 columns]
